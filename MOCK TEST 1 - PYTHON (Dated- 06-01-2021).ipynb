# %% [markdown]
# ### MOCK TEST 1 - PYTHON (Dated- 06/01/2021)"""
# - Submitted By PALASH CHATTERJEE
# * #Batch - NOV 7 DS & AI

# %%
"""
QUESTION:
Write a python function to accept user inputs, store it in a list and compute the highest number out of it.
User can enter as many numbers as he/she wants.
Take care of following things:
1.	Input must be entered by user
2.	Exception handling
3.	Null values
4.	Errors
5.	Datatypes
Output of the function must be a number.
It should accept correct values and for incorrect values, an error message must be displayed to the user.
"""

# %%
# CODE NO 1 (MOCK TEST 1)
x=0
y=[]
count=0
def maxi():
    global count
    while (count==0):
        print("Enter '=' when complete entering the numbers")
        count+=1
    n=input("Enter your number no.{} : ".format(count))
    count+=1
    try:
        x=float(n)
        y.append(x)
        maxi()
    except:
        if(n=="="):
            count-=2
            cal_large()
        else:
            print("You have entered other than a number")
            print("Enter 1 to continue entering number")
            print("Enter 2 to Find the Maximum")
            k=input()
            count-=1
            if k=="1":
                maxi()
            elif k=="2":
                cal_large()
            else:
                print("You entered a wrong choice")

def cal_large():
        large = y[0]
        for i in y:
            if i>large:
                large=i
        global count
        print("")
        print ("The largest of all the {} numbers is : ".format(count), large)
        print(" \n Your List of numbers is : ",y)
        print(" \n Do You want to again Find The Maximum of Numbers ?? \n Press 'Y' for YES & 'N' for NO")
        m=input()
        count=0
        if (m=='Y' or m=='y'):
            maxi()
        elif (m=='N' or m=='n'):
            print("THANK YOU for using the program")
            exit()
        else:
            print ("Wrong Choice")

print('Welcome To "Find The MAXIMUM" \n Let\'s help you Find the Largest Value for your Numbers')
print(" \n Press 'Y' to start OR 'N' to exit")
opt =input()
if (opt=='Y' or opt=='y'):
    maxi()
elif (opt=='N' or opt=='n'):
    print("THANK YOU but you missed a opportunity using the program")
    exit()
else:
    print("Wrong Choice")
# Out:
# Welcome To "Find The MAXIMUM"
#  Let's help you Find the Largest Value for your Numbers
#
#  Press 'Y' to start OR 'N' to exit
# y
# Enter '=' when complete entering the numbers
# Enter your number no.1 : 125
# Enter your number no.2 : 328
# Enter your number no.3 : 462
# Enter your number no.4 : 399
# Enter your number no.5 : 276
# Enter your number no.6 : 524
# Enter your number no.7 : 111
# Enter your number no.8 : 240
# Enter your number no.9 : =
#
# The largest of all the 8 numbers is :  524.0
#
#  Your List of numbers is :  [125.0, 328.0, 462.0, 399.0, 276.0, 524.0, 111.0, 240.0]
#
#  Do You want to again Find The Maximum of Numbers ??
#  Press 'Y' for YES & 'N' for NO
# y
# Enter '=' when complete entering the numbers
# Enter your number no.1 : 125
# Enter your number no.2 : 328
# Enter your number no.3 : 462
# Enter your number no.4 : 399
# Enter your number no.5 : KK
# You have entered other than a number
# Enter 1 to continue entering number
# Enter 2 to Find the Maximum
# ...

# %%
"""
Check list:
1. Program gives the highest number from a list -        DONE
2. User can enter as many numbers as he/she wants. -     SATISFIED
3. Input must be entered by user -                       SATISFIED
4. Exception handling, Null values, Errors, Datatypes -  TAKEN CARE
5. Output of the function must be a number. -            SATISFIED
6. It should accept correct values and for incorrect values, an error message must be displayed to the user. - SATISFIED
7. User Friendly -                                       DONE
"""
